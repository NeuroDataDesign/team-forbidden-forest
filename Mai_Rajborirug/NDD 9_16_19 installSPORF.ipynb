# %% [markdown]
# # week 9/16/2019
#
# ## Using SPORF in window 10
# ### 1. installing Linux and Jupyter Notebook in Linux
# 1. follow the [link](https://docs.microsoft.com/en-us/windows/wsl/install-win10)'s command
#     *  _Enable-WindowsOptionalFeature -Online -FeatureName Microsoft-Windows-Subsystem-Linux_
#     * found the error below

# %%
from IPython.display import Image
Image(filename='9_16_01.png',width=500) # sample of 2D data in SPORF [Jovo's presentation]

# %% [markdown]
# 2. Debug by follow the [link](https://social.technet.microsoft.com/Forums/windows/en-US/9abf7f68-7ce7-4140-8795-749f04e529e3/solved-cant-enable-windows-subsystem-for-linux?forum=win10itprogeneral)
#     * rightclick powerShell -> run as administrator
#     * control panel -> Programs -> Turn Windows features on or off -> check' Window Subsystem for Linux -> restart
# * Download 'Ubuntu' from Microsoft store
# * Install and create username and password
#     * The list of acceptable usearname is [here](https://askubuntu.com/questions/232742/failed-to-create-user-due-to-regular-expression-error). Usually the system accepts 'a'-'z' as the first character and 'a'-'z','0'-'9','_', and '-'
# * Command Download Anaconda 3
#     * _wget https://repo.continuum.io/archive/Anaconda3-2019.07-Linux-x86_64.sh_
# * Run the following command to unzip and install the package
#     * from the file direction the name in
#     * 2019-09-16 10:21:26 (9.18 MB/s) - ‘Anaconda3-2019.07-Linux-x86_64.sh’ saved [541906131/541906131]' abd use command
#     * _bash Anaconda3-5.0.1-Linux-x86_64.sh_
# * Run the following command to install jupyter notebook
#     * _conda install jupyter notebook_
# * To run jupyter notebook, run the command
#     * _jupyter notebook_
# * To close jupyter notebook
#     * to copy, press _Ctrl+ C_ in Ubantu
#     * to paste, paste _Ctrl + Alt + t_ in Ubantu
#
# ### 2. installing SPORF in linux
# 1. To installing SPORF, follows Shumin's [note](https://github.com/NeuroDataDesign/team-forbidden-forest/blob/master/ShumingXu/Installing%20SPORF%20on%20WIN10) number 6 and continue or follow [this](https://rerf.neurodata.io/install.html)
# ### 3. Build from source
# 1. Get the source files (access to github respitory)
#     * _git clone https://github.com/neurodata/RerF.git_
# - Navigate to Python directory
#     - _cd RerF/Python_
# - Clean out old installation (skip if fresh install)
#     - _python setup.py clean --all_
# - Build using pip
#     - _pip install -e_
